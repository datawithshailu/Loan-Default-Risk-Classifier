# %%
# Step 1: Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# This line makes your graphs look clean
# %matplotlib inline

# %%
import pandas as pd

# Step 2: Load the CSV from full file path
file_path = r"C:\Users\PREETHIKA RAVIRAJ\Downloads\archive (1)\loan_default.csv"
df = pd.read_csv(file_path)

# Show top 5 rows
df.head()
# Out:
#       ID  year loan_limit             Gender approv_in_adv loan_type  \
# 0  24890  2019         cf  Sex Not Available         nopre     type1
# 1  24891  2019         cf               Male         nopre     type2
# 2  24892  2019         cf               Male           pre     type1
# 3  24893  2019         cf               Male         nopre     type1
# 4  24894  2019         cf              Joint           pre     type1
#
#   loan_purpose Credit_Worthiness open_credit business_or_commercial  ...  \
# 0           p1                l1        nopc                  nob/c  ...
# 1           p1                l1        nopc                    b/c  ...
# 2           p1                l1        nopc                  nob/c  ...
# 3           p4                l1        nopc                  nob/c  ...
# 4           p1                l1        nopc                  nob/c  ...
#
#    credit_type  Credit_Score  co-applicant_credit_type    age  \
# ...

# %%
# Step 3: Basic Data Cleaning

# Check column names and data types
print("🔹 Column Info:")
print(df.info())

# Check for missing values
print("\n🔹 Missing Values:")
print(df.isnull().sum())

# Check for duplicate rows
print("\n🔹 Duplicates:")
print(df.duplicated().sum())
# Out:
# 🔹 Column Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148670 entries, 0 to 148669
# Data columns (total 34 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   ID                         148670 non-null  int64
#  1   year                       148670 non-null  int64
#  2   loan_limit                 145326 non-null  object
#  3   Gender                     148670 non-null  object
#  4   approv_in_adv              147762 non-null  object
#  5   loan_type                  148670 non-null  object
#  6   loan_purpose               148536 non-null  object
#  7   Credit_Worthiness          148670 non-null  object
#  8   open_credit                148670 non-null  object
#  9   business_or_commercial     148670 non-null  object
#  10  loan_amount                148670 non-null  int64
#  11  rate_of_interest           112231 non-null  float64
# ...

# %%
# Convert age to numeric (some values may be strings)
df['age'] = pd.to_numeric(df['age'], errors='coerce')

# Now check again how many are null
print("Missing in 'age':", df['age'].isnull().sum())
# Out:
# Missing in 'age': 148670

# %%
# Let's inspect the first few values in 'age'
df['age'].unique()[:20]
# Out:
# array([nan])

# %%
# Drop the age column entirely
df.drop(columns=['age'], inplace=True)

# %%
df['loan_limit'] = df['loan_limit'].fillna('Unknown')
df['approv_in_adv'] = df['approv_in_adv'].fillna('Unknown')
df['loan_purpose'] = df['loan_purpose'].fillna('Unknown')
df['Neg_ammortization'] = df['Neg_ammortization'].fillna('No')
df['term'] = df['term'].fillna(df['term'].median())
df['submission_of_application'] = df['submission_of_application'].fillna('Unknown')

# %%
num_cols = ['property_value', 'income', 'LTV']  # removed 'age'

for col in num_cols:
    df[col] = df[col].fillna(df[col].median())

# %%
# These columns have lots of missing data, so we drop the rows where they’re missing
df.dropna(subset=['rate_of_interest', 'Interest_rate_spread', 'Upfront_charges', 'dtir1'], inplace=True)

# %%
# Check again if we have any missing values left
df.isnull().sum()
# Out:
# ID                           0
# year                         0
# loan_limit                   0
# Gender                       0
# approv_in_adv                0
# loan_type                    0
# loan_purpose                 0
# Credit_Worthiness            0
# open_credit                  0
# business_or_commercial       0
# loan_amount                  0
# rate_of_interest             0
# Interest_rate_spread         0
# Upfront_charges              0
# term                         0
# Neg_ammortization            0
# interest_only                0
# lump_sum_payment             0
# property_value               0
# construction_type            0
# occupancy_type               0
# Secured_by                   0
# total_units                  0
# income                       0
# credit_type                  0
# Credit_Score                 0
# co-applicant_credit_type     0
# submission_of_application    0
# LTV                          0
# Region                       0
# ...

# %%
import pandas as pd

# ✅ Load the actual dataset you extracted from the ZIP file
df = pd.read_csv(r"C:\Users\PREETHIKA RAVIRAJ\Downloads\archive (1)\Loan_Default.csv")

# ✅ Check target column
print(df['Status'].value_counts())
# Out:
# Status
# 0    112031
# 1     36639
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='Status', y='income', data=df)
plt.title("Income vs Default Status")
plt.xlabel("Default Status")
plt.ylabel("Income")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='Status', y='Credit_Score', data=df)
plt.title("Credit Score vs Default Status")
plt.xlabel("Default Status")
plt.ylabel("Credit Score")
plt.show()

# %%
loan_purpose_default = df.groupby('loan_purpose')['Status'].mean().sort_values(ascending=False)

loan_purpose_default.plot(kind='bar', figsize=(10,5), color='tomato')
plt.title("Default Rate by Loan Purpose")
plt.ylabel("Default Rate")
plt.xlabel("Loan Purpose")
plt.xticks(rotation=45)
plt.show()

# %%
features = ['income', 'Credit_Score', 'loan_amount', 'loan_purpose']
target = 'Status'

# Make a copy of just these columns
model_data = df[features + [target]].copy()

# %%
model_data = pd.get_dummies(model_data, columns=['loan_purpose'], drop_first=True)

# %%
from sklearn.model_selection import train_test_split

X = model_data.drop('Status', axis=1)
y = model_data['Status']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X.isnull().sum()
# Out:
# income             9150
# Credit_Score          0
# loan_amount           0
# loan_purpose_p2       0
# loan_purpose_p3       0
# loan_purpose_p4       0
# dtype: int64

# %%
# Fill missing values in X (features)
X = X.fillna(X.median(numeric_only=True))

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
X_train = X_train.fillna(X_train.median(numeric_only=True))
X_test = X_test.fillna(X_test.median(numeric_only=True))

# %%
model = LogisticRegression(max_iter=1000, class_weight='balanced')

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(class_weight='balanced', random_state=42)
rf_model.fit(X_train, y_train)

# Predict
y_pred_rf = rf_model.predict(X_test)

# Evaluate
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

print("Accuracy:", accuracy_score(y_test, y_pred_rf))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_rf))
print("Classification Report:\n", classification_report(y_test, y_pred_rf))
# Out:
# Accuracy: 0.7346023631757136
# Confusion Matrix:
#  [[30872  2815]
#  [ 9022  1892]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.77      0.92      0.84     33687
#            1       0.40      0.17      0.24     10914
#
#     accuracy                           0.73     44601
#    macro avg       0.59      0.54      0.54     44601
# weighted avg       0.68      0.73      0.69     44601
